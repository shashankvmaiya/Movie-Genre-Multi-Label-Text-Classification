# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#MODELING" data-toc-modified-id="MODELING-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>MODELING</a></span><ul class="toc-item"><li><span><a href="#Binary-Relevance" data-toc-modified-id="Binary-Relevance-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Binary Relevance</a></span><ul class="toc-item"><li><span><a href="#TF-IDF-+-Naive-Bayes" data-toc-modified-id="TF-IDF-+-Naive-Bayes-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>TF-IDF + Naive Bayes</a></span><ul class="toc-item"><li><span><a href="#Summary-of-findings" data-toc-modified-id="Summary-of-findings-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>Summary of findings</a></span></li><li><span><a href="#GridSearchCV" data-toc-modified-id="GridSearchCV-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span>GridSearchCV</a></span></li><li><span><a href="#Using-the-best-parameters-obtained-from-gridsearch-using-0.5-Probability-threshold" data-toc-modified-id="Using-the-best-parameters-obtained-from-gridsearch-using-0.5-Probability-threshold-1.1.1.3"><span class="toc-item-num">1.1.1.3&nbsp;&nbsp;</span>Using the best parameters obtained from gridsearch using 0.5 Probability threshold</a></span></li><li><span><a href="#Use-customized-predict-function" data-toc-modified-id="Use-customized-predict-function-1.1.1.4"><span class="toc-item-num">1.1.1.4&nbsp;&nbsp;</span>Use customized predict function</a></span></li><li><span><a href="#Best-Naive-Bayes-So-far" data-toc-modified-id="Best-Naive-Bayes-So-far-1.1.1.5"><span class="toc-item-num">1.1.1.5&nbsp;&nbsp;</span>Best Naive Bayes So far</a></span></li></ul></li><li><span><a href="#TF-IDF-+-SVC" data-toc-modified-id="TF-IDF-+-SVC-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>TF-IDF + SVC</a></span><ul class="toc-item"><li><span><a href="#Summary" data-toc-modified-id="Summary-1.1.2.1"><span class="toc-item-num">1.1.2.1&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#Grid-Search-CV" data-toc-modified-id="Grid-Search-CV-1.1.2.2"><span class="toc-item-num">1.1.2.2&nbsp;&nbsp;</span>Grid Search CV</a></span></li><li><span><a href="#Trying-out-individual-hyperparameters" data-toc-modified-id="Trying-out-individual-hyperparameters-1.1.2.3"><span class="toc-item-num">1.1.2.3&nbsp;&nbsp;</span>Trying out individual hyperparameters</a></span></li></ul></li><li><span><a href="#TF-IDF-+-Logistic-Regression" data-toc-modified-id="TF-IDF-+-Logistic-Regression-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>TF-IDF + Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#Summary" data-toc-modified-id="Summary-1.1.3.1"><span class="toc-item-num">1.1.3.1&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#GridSearchCV" data-toc-modified-id="GridSearchCV-1.1.3.2"><span class="toc-item-num">1.1.3.2&nbsp;&nbsp;</span>GridSearchCV</a></span></li><li><span><a href="#A-Single-Hyperparameter" data-toc-modified-id="A-Single-Hyperparameter-1.1.3.3"><span class="toc-item-num">1.1.3.3&nbsp;&nbsp;</span>A Single Hyperparameter</a></span></li></ul></li><li><span><a href="#CountVectorizer-+-SVC" data-toc-modified-id="CountVectorizer-+-SVC-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>CountVectorizer + SVC</a></span><ul class="toc-item"><li><span><a href="#Summary" data-toc-modified-id="Summary-1.1.4.1"><span class="toc-item-num">1.1.4.1&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#GridSearchCV" data-toc-modified-id="GridSearchCV-1.1.4.2"><span class="toc-item-num">1.1.4.2&nbsp;&nbsp;</span>GridSearchCV</a></span></li><li><span><a href="#Single-Hyperparameter-Tuning" data-toc-modified-id="Single-Hyperparameter-Tuning-1.1.4.3"><span class="toc-item-num">1.1.4.3&nbsp;&nbsp;</span>Single Hyperparameter Tuning</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import missingno as msno
import re
import os.path
import math
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.cross_validation import KFold
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from scipy import sparse
from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score
from sklearn.linear_model import LogisticRegression
from skmultilearn.problem_transform import LabelPowerset
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier


import nltk
from wordcloud import WordCloud
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import unicodedata

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

nltk.download('stopwords')
nltk.download('wordnet')

#plt.style.use('fivethirtyeight')
sns.set_style("whitegrid")
sns.set_context("talk", font_scale=0.8)

from helper_functions import *
overall_f1_score_v1_cv = make_scorer(overall_f1_score_v1, greater_is_better=True)
# Out:
# C:\Users\smaiya\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\smaiya\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\smaiya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\smaiya\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # MODELING

# %% [markdown]
# **Loading the input**

# %%
mydata_train = pd.read_csv('./../Data/preprocessed/movies_genres_train_preprocessed.csv')
mydata_test = pd.read_csv('./../Data/preprocessed/movies_genres_test_preprocessed.csv')
mydata = pd.read_csv('../Data/movies_genres.csv', delimiter='\t')

train_X, train_y = mydata_train['plot'], mydata_train.drop(['title', 'plot', 'plot_lang'], axis=1)
test_X, test_y = mydata_test['plot'], mydata_test.drop(['title', 'plot', 'plot_lang'], axis=1)

category_columns = train_y.columns

# %% [markdown]
# ## Binary Relevance
# Binary Relevance classification consists of fitting one classifier per class. For each classifier, the class is fitted against all the other classes - hence n_classes classifiers are needed. The union of all classes that were predicted is taken as the multi-label output. We use the inbuilt sklearn OneVsRestClassifier function to achieve this multi-label classification.
#
# OnevsRestClassifier is commonly used for multi-class classification; however, it also supports multi-label classification. To use this feature, feed the classifier an indicator matrix, in which cell [i, j] indicates the presence of label j in sample i.
#
# Probability threshold used for classifying each genres is based on the frequency of its occurence

# %%
prob_thresh = get_prob_thresh(mydata[category_columns], thresh_sel=2)
prob_thresh
# Out:
# Action         0.105594
# Adult          0.000521
# Adventure      0.087402
# Animation      0.097010
# Biography      0.011818
# Comedy         0.289008
# Crime          0.129025
# Documentary    0.102565
# Drama          0.391581
# Family         0.131440
# Fantasy        0.060609
# Game-Show      0.017450
# History        0.022714
# Horror         0.021938
# Music          0.024208
# Musical        0.005077
# Mystery        0.102616
# News           0.033662
# Reality-TV     0.105261
# Romance        0.163609
# Sci-Fi         0.073878
# Short          0.004932
# Sport          0.016596
# Talk-Show      0.044823
# Thriller       0.075533
# War            0.012006
# Western        0.023559
# dtype: float64

# %% [markdown]
# ### TF-IDF + Naive Bayes
#
# #### Summary of findings
# * Overall F1-score for using default accuracy scoring + 0.5 probability threshold for making decisions = 0.64
# * The model can be further improved by using optimal probability thresholds to 0.75 (this reduces the precision but increases the recall). Optimal probability threshold = probability of a movie being that genre
# * The best TF-IDF + Naive Bayes have an overall F1 score of 0.76 which uses the below hyperparameters
#     * TfidfVectorizer(max_df=0.5, min_df=2, ngram_range=(1, 2))
#     * OneVsRestClassifier(MultinomialNB(alpha=0.01, fit_prior=True, class_prior=None))

# %% [markdown]
# #### GridSearchCV

# %%
pipeline = Pipeline([
                ('tfidf', TfidfVectorizer()),
                ('clf', OneVsRestClassifier(MultinomialNB(fit_prior=True, class_prior=None)))
            ])
# sorted(pipeline.get_params().keys()) # -- to obtain the GridSearchCV parameter names
parameters = {
                'tfidf__max_df': (0.25, 0.5, 0.75),
                'tfidf__ngram_range': [(1, 2)],
                'tfidf__min_df': [1, 3, 5],
                'clf__estimator__alpha': (1e-2, 1e-3)
            }

grid_search_cv = GridSearchCV(pipeline, parameters, cv=2, n_jobs=3, verbose=10)
grid_search_cv.fit(train_X, train_y)

print()
print("Best parameters set:")
print (grid_search_cv.best_estimator_.steps)
print()

# measuring performance on test set
print ("Applying best classifier on test data:")
best_clf = grid_search_cv.best_estimator_
prob, predictions = multi_label_predict(best_clf, test_X, thresh_sel=2, thresh_offset=0) 
accuracy(test_y, predictions)
# Out:
# Fitting 2 folds for each of 18 candidates, totalling 36 fits
# [Parallel(n_jobs=3)]: Done   2 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=3)]: Done   7 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=3)]: Done  12 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=3)]: Done  19 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=3)]: Done  26 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=3)]: Done  36 out of  36 | elapsed: 13.0min finished
# Best parameters set:
# [('tfidf', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.5, max_features=None, min_df=5,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)), ('clf', OneVsRestClassifier(estimator=MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True),
#           n_jobs=1))]
#
# Applying best classifier on test data:
#              Precision  Recall  F1-Score  Support
# Action            0.78    0.71      0.74   4321.0
# Adult             0.17    0.09      0.12     11.0
# Adventure         0.70    0.70      0.70   3496.0
# Animation         0.79    0.79      0.79   3333.0
# Biography         0.25    0.46      0.33    354.0
# Comedy            0.79    0.75      0.77   7320.0
# Crime             0.78    0.81      0.79   4453.0
# Documentary       0.52    0.76      0.62   1863.0
# Drama             0.84    0.84      0.84  11067.0
# Family            0.78    0.71      0.74   4173.0
# Fantasy           0.72    0.67      0.69   2643.0
# Game-Show         0.63    0.86      0.73    450.0
# History           0.39    0.66      0.49    623.0
# Horror            0.51    0.47      0.49    854.0
# Music             0.59    0.61      0.60    654.0
# Musical           0.53    0.50      0.51    182.0
# Mystery           0.69    0.73      0.71   4114.0
# News              0.54    0.83      0.66    681.0
# Reality-TV        0.64    0.78      0.70   1748.0
# Romance           0.77    0.74      0.76   4581.0
# Sci-Fi            0.73    0.70      0.72   3055.0
# Short             0.28    0.25      0.26    142.0
# Sport             0.54    0.69      0.61    426.0
# Talk-Show         0.57    0.86      0.68    809.0
# Thriller          0.62    0.67      0.65   3254.0
# War               0.52    0.71      0.60    388.0
# Western           0.58    0.79      0.67    445.0
# Avg/Total         0.73    0.75      0.74  65440.0

# %% [markdown]
# #### Using the best parameters obtained from gridsearch using 0.5 Probability threshold

# %%
pipeline = Pipeline([
                ('tfidf', TfidfVectorizer(max_df=0.5, ngram_range=(1, 2))),
                ('clf', OneVsRestClassifier(MultinomialNB(alpha=0.01, fit_prior=True, class_prior=None)))
            ])
pipeline.fit(train_X, train_y)
predictions = pipeline.predict(test_X)
accuracy(test_y, predictions)
# Out:
#              Precision  Recall  F1-Score  Support
# Action            0.98    0.43      0.59   4321.0
# Adult             0.00    0.00      0.00     11.0
# Adventure         0.96    0.40      0.56   3496.0
# Animation         0.97    0.51      0.67   3333.0
# Biography         0.83    0.03      0.05    354.0
# Comedy            0.91    0.63      0.75   7320.0
# Crime             0.93    0.56      0.70   4453.0
# Documentary       0.84    0.45      0.58   1863.0
# Drama             0.88    0.83      0.85  11067.0
# Family            0.97    0.42      0.59   4173.0
# Fantasy           0.98    0.32      0.49   2643.0
# Game-Show         0.98    0.50      0.66    450.0
# History           0.89    0.15      0.26    623.0
# Horror            0.97    0.07      0.14    854.0
# Music             0.97    0.30      0.45    654.0
# Musical           0.86    0.03      0.06    182.0
# Mystery           0.93    0.40      0.56   4114.0
# News              0.94    0.52      0.67    681.0
# Reality-TV        0.92    0.53      0.67   1748.0
# Romance           0.96    0.60      0.74   4581.0
# Sci-Fi            0.98    0.40      0.57   3055.0
# Short             0.67    0.01      0.03    142.0
# Sport             0.99    0.19      0.32    426.0
# Talk-Show         0.89    0.60      0.72    809.0
# Thriller          0.97    0.27      0.42   3254.0
# War               1.00    0.08      0.15    388.0
# Western           0.99    0.28      0.43    445.0
# Avg/Total         0.93    0.52      0.64  65440.0

# %% [markdown]
# #### Use customized predict function

# %% [markdown]
# thresh_offset=0:0.05:0.5
# best F1score = 0.75 with thresh_offset = 0

# %%
pipeline = Pipeline([
                ('tfidf', TfidfVectorizer(max_df=0.5, ngram_range=(1, 2))),
                ('clf', OneVsRestClassifier(MultinomialNB(alpha=0.01, fit_prior=True, class_prior=None)))
            ])
pipeline.fit(train_X, train_y)

prob, predictions = multi_label_predict(pipeline, test_X, prob_thresh) 
accuracy(test_y, predictions)
# Out:
#              Precision  Recall  F1-Score  Support
# Action            0.91    0.63      0.74   4321.0
# Adult             0.00    0.00      0.00     11.0
# Adventure         0.86    0.61      0.71   3496.0
# Animation         0.91    0.72      0.80   3333.0
# Biography         0.82    0.10      0.19    354.0
# Comedy            0.85    0.74      0.79   7320.0
# Crime             0.86    0.77      0.81   4453.0
# Documentary       0.68    0.68      0.68   1863.0
# Drama             0.86    0.85      0.86  11067.0
# Family            0.89    0.64      0.74   4173.0
# Fantasy           0.92    0.54      0.68   2643.0
# Game-Show         0.91    0.68      0.78    450.0
# History           0.74    0.38      0.50    623.0
# Horror            0.94    0.21      0.34    854.0
# Music             0.87    0.47      0.61    654.0
# Musical           0.94    0.09      0.17    182.0
# Mystery           0.82    0.64      0.72   4114.0
# News              0.81    0.71      0.76    681.0
# Reality-TV        0.78    0.73      0.75   1748.0
# Romance           0.86    0.72      0.78   4581.0
# Sci-Fi            0.91    0.62      0.74   3055.0
# Short             0.83    0.04      0.07    142.0
# Sport             0.92    0.37      0.53    426.0
# Talk-Show         0.73    0.82      0.77    809.0
# Thriller          0.83    0.52      0.64   3254.0
# War               0.93    0.31      0.47    388.0
# Western           0.93    0.61      0.74    445.0
# Avg/Total         0.86    0.68      0.75  65440.0

# %% [markdown]
# #### Best Naive Bayes So far

# %%
pipeline = Pipeline([
                ('tfidf', TfidfVectorizer(max_df=0.5, min_df=2, ngram_range=(1, 2))),
                ('clf', OneVsRestClassifier(MultinomialNB(alpha=0.01, fit_prior=True, class_prior=None)))
            ])
pipeline.fit(train_X, train_y)

prob, predictions = multi_label_predict(pipeline, test_X, prob_thresh) 
accuracy(test_y, predictions)
# Out:
#              Precision  Recall  F1-Score  Support
# Action            0.84    0.70      0.76   4321.0
# Adult             0.00    0.00      0.00     11.0
# Adventure         0.78    0.70      0.74   3496.0
# Animation         0.85    0.79      0.82   3333.0
# Biography         0.45    0.32      0.38    354.0
# Comedy            0.83    0.73      0.78   7320.0
# Crime             0.82    0.80      0.81   4453.0
# Documentary       0.60    0.74      0.66   1863.0
# Drama             0.86    0.85      0.85  11067.0
# Family            0.84    0.68      0.75   4173.0
# Fantasy           0.81    0.65      0.72   2643.0
# Game-Show         0.74    0.85      0.79    450.0
# History           0.51    0.60      0.55    623.0
# Horror            0.74    0.42      0.53    854.0
# Music             0.67    0.61      0.64    654.0
# Musical           0.94    0.37      0.54    182.0
# Mystery           0.75    0.71      0.73   4114.0
# News              0.64    0.81      0.71    681.0
# Reality-TV        0.73    0.76      0.74   1748.0
# Romance           0.84    0.72      0.78   4581.0
# Sci-Fi            0.80    0.71      0.75   3055.0
# Short             0.73    0.15      0.26    142.0
# Sport             0.72    0.64      0.67    426.0
# Talk-Show         0.62    0.86      0.72    809.0
# Thriller          0.70    0.64      0.67   3254.0
# War               0.72    0.63      0.68    388.0
# Western           0.69    0.76      0.72    445.0
# Avg/Total         0.80    0.73      0.76  65440.0

# %% [markdown]
# **Looking into the Adult movie section. Both Precision and Recall = 0!**
# * Just 11 occurences
# * Probability of adult genre is of the order of 10^-10, while probability for comedy or drama genre is way higher
# * number of occurences of comedy and drama is way higher in the training data set. they are probably causing some effect there

# %%
prob[test_y['Adult']==1]
# Out:
#          Action         Adult  Adventure  Animation     Biography    Comedy  \
# 645    0.010804  6.006202e-08   0.069670   0.004839  1.086440e-04  0.627602
# 1621   0.004642  1.946277e-09   0.002828   0.007518  3.457040e-04  0.573129
# 7248   0.011131  6.065165e-12   0.009674   0.011140  2.837362e-06  0.022234
# 8905   0.089500  5.180129e-08   0.015094   0.161573  4.211464e-04  0.029176
# 9535   0.001510  7.279494e-09   0.000486   0.013971  9.277890e-05  0.115174
# 9666   0.023313  4.238133e-08   0.012350   0.000974  4.671967e-04  0.015601
# 11603  0.000061  1.053842e-05   0.000012   0.001156  9.657133e-07  0.304091
# 11604  0.000110  2.281579e-06   0.000478   0.004473  2.358317e-05  0.240267
# 12271  0.000015  4.811720e-09   0.000008   0.000070  2.771903e-03  0.183441
# 16603  0.001984  8.051792e-08   0.003106   0.019348  1.837651e-04  0.301463
# 16604  0.000235  1.162768e-05   0.000691   0.000602  6.661992e-05  0.931744
#
#           Crime  Documentary     Drama    Family      ...               News  \
# 645    0.005031     0.000453  0.391163  0.004529      ...       1.782965e-05
# 1621   0.017850     0.024261  0.355467  0.010071      ...       7.061243e-04
# 7248   0.003051     0.002113  0.473925  0.000545      ...       4.026602e-07
# 8905   0.002151     0.002130  0.061547  0.001006      ...       2.172968e-05
# 9535   0.002326     0.000212  0.478800  0.016750      ...       2.488113e-06
# 9666   0.062417     0.003114  0.305312  0.002454      ...       4.698653e-04
# 11603  0.000028     0.000005  0.125800  0.003541      ...       2.864810e-07
# 11604  0.000036     0.000257  0.056527  0.004385      ...       2.032413e-04
# 12271  0.000169     0.289930  0.000062  0.000195      ...       7.257557e-03
# 16603  0.000747     0.066687  0.044410  0.029699      ...       4.219289e-03
# 16604  0.000528     0.002116  0.170008  0.007060      ...       2.221080e-05
#
#        Reality-TV   Romance    Sci-Fi         Short         Sport  \
# 645      0.001203  0.058998  0.013937  4.650177e-06  8.749735e-06
# 1621     0.001408  0.004189  0.007441  7.835707e-06  1.068696e-03
# 7248     0.000016  0.001490  0.023485  7.207185e-08  2.540476e-07
# 8905     0.000844  0.002013  0.030143  1.456367e-05  1.004395e-04
# 9535     0.000419  0.007147  0.004132  8.829512e-06  3.129032e-06
# 9666     0.000376  0.003197  0.019467  4.836328e-05  2.831070e-05
# 11603    0.007223  0.056148  0.000028  3.173625e-06  3.872073e-06
# 11604    0.001133  0.004562  0.000085  3.828528e-05  2.547699e-05
# 12271    0.006589  0.000025  0.000034  7.244125e-06  9.280305e-04
# 16603    0.099966  0.032711  0.000836  1.387299e-05  6.958256e-04
# 16604    0.011109  0.134151  0.001040  4.077865e-05  6.100928e-05
#
#           Talk-Show  Thriller       War       Western
# 645    1.280094e-05  0.005474  0.001672  9.161415e-05
# 1621   1.709159e-03  0.003462  0.000046  6.334244e-06
# 7248   7.893085e-08  0.002732  0.000002  2.230509e-06
# 8905   9.552750e-05  0.004765  0.000072  5.339401e-07
# 9535   7.312184e-06  0.011499  0.000015  1.607308e-04
# 9666   7.092957e-04  0.077290  0.000243  1.105052e-04
# 11603  8.901999e-06  0.000081  0.000002  1.281780e-06
# 11604  8.779008e-05  0.000251  0.000070  1.151356e-05
# 12271  2.712555e-02  0.000032  0.000004  7.854489e-07
# 16603  7.499869e-02  0.000500  0.000011  2.730205e-05
# 16604  1.598329e-04  0.000733  0.002058  1.755589e-04
#
# [11 rows x 27 columns]

# %%
test_X.loc[16604]
# Out:
# 'beautiful gia vacation order room service food hungry decide seduce straight waiter gia use body feet arouse waiters curiosity waiter shock gias huge cock late turn back'

# %%
word_weight = analyze_plot_genre(pipeline, test_X.loc[16604], ['Adult', 'Comedy', 'Drama']) 
word_weight
# Out:
#          word     Adult    Comedy     Drama
# 0   beautiful  0.000138  0.260447  0.247754
# 1         gia  0.002962  0.092503  0.899637
# 2    vacation  0.000009  0.418793  0.220332
# 3       order  0.000026  0.307751  0.400794
# 4        room  0.000171  0.332733  0.382707
# 5     service  0.000005  0.293978  0.417015
# 6        food  0.000004  0.205500  0.125959
# 7      hungry  0.000295  0.304133  0.140442
# 8      decide  0.000029  0.405175  0.401906
# 9      seduce  0.000326  0.264485  0.659766
# 10   straight  0.000100  0.331025  0.325533
# 11     waiter  0.000041  0.631067  0.325975
# 12        gia  0.002962  0.092503  0.899637
# 13        use  0.000047  0.278383  0.297766
# 14       body  0.000177  0.184272  0.451453
# 15       feet  0.000013  0.225094  0.205777
# 16     arouse  0.000047  0.340487  0.602151
# 17    waiters  0.000156  0.415587  0.314811
# 18  curiosity  0.000052  0.271176  0.264955
# 19     waiter  0.000041  0.631067  0.325975
# 20      shock  0.000121  0.221827  0.530401
# 21       gias  0.001125  0.216727  0.978031
# 22       huge  0.000295  0.257007  0.256909
# 23       cock  0.011295  0.141895  0.506256
# 24       late  0.000031  0.313704  0.430181
# 25       turn  0.000102  0.329730  0.395874
# 26       back  0.000033  0.306346  0.428436

# %%
#df_good = get_features_tfidf(pipeline, ['Adult', 'Comedy', 'Drama'], num_features=0, prob_only=True)
df_good = get_features_tfidf(pipeline, category_columns)
df_good
# Out:
#                                  P1                            P2  \
# Action              waldek (p=1.00)                lowie (p=1.00)
# Adult            wet pussy (p=0.86)              pussies (p=0.85)
# Adventure              buz (p=1.00)               yakari (p=1.00)
# Animation          caillou (p=1.00)                  piu (p=1.00)
# Biography         batiatus (p=0.99)               garrow (p=0.99)
# Comedy              waldek (p=1.00)              paulien (p=1.00)
# Crime            mcgarrett (p=1.00)                lupin (p=1.00)
# Documentary    rooney talk (p=1.00)  rebroadcast segment (p=1.00)
# Drama              carolee (p=1.00)              simonne (p=1.00)
# Family             caillou (p=1.00)              beakman (p=1.00)
# Fantasy              luffy (p=1.00)             inuyasha (p=1.00)
# Game-Show        play know (p=1.00)                  myf (p=1.00)
# History               huie (p=1.00)              lesueur (p=1.00)
# Horror            sam dean (p=1.00)              castiel (p=1.00)
# Music        anita coleman (p=1.00)       jimmie jackson (p=1.00)
# Musical             wibbly (p=0.99)           fresh beat (p=0.99)
# Mystery              unsub (p=1.00)                kensi (p=1.00)
# News           rooney talk (p=1.00)  rebroadcast segment (p=1.00)
# Reality-TV             hef (p=1.00)               lyndah (p=1.00)
# Romance            carolee (p=1.00)               steffy (p=1.00)
# Sci-Fi               tealc (p=1.00)             wordgirl (p=1.00)
# Short                richy (p=1.00)              mr marc (p=0.99)
# Sport                zatch (p=1.00)                 kiyo (p=1.00)
# Talk-Show          actorse (p=1.00)    interview variety (p=1.00)
# Thriller             unsub (p=1.00)                kensi (p=1.00)
# War             binghamton (p=1.00)              shuhuan (p=1.00)
# Western            trampas (p=1.00)           north fork (p=1.00)
#
#                                          P3                             P4  \
# Action                       lupin (p=1.00)          sanitechniek (p=1.00)
# Adult                  lick others (p=0.83)                darcie (p=0.83)
# Adventure                    tealc (p=1.00)                 luffy (p=1.00)
# Animation           pocket dragons (p=1.00)                 pingu (p=1.00)
# Biography                     ryge (p=0.99)             sren ryge (p=0.99)
# Comedy                       lowie (p=1.00)        weekend update (p=1.00)
# Crime                        mahir (p=1.00)                 unsub (p=1.00)
# Documentary       australian story (p=1.00)   rebroadcast profile (p=1.00)
# Drama                       waldek (p=1.00)                steffy (p=1.00)
# Family                       pingu (p=1.00)                yakari (p=1.00)
# Fantasy                     endora (p=1.00)                 kuzco (p=1.00)
# Game-Show              alan brough (p=1.00)          myf warhurst (p=1.00)
# History                      nucky (p=1.00)                 staib (p=1.00)
# Horror                    dean sam (p=1.00)               duckula (p=0.99)
# Music        televisions hollywood (p=1.00)        hollywood host (p=1.00)
# Musical                      tweeg (p=0.99)                sarina (p=0.99)
# Mystery                malloy reed (p=1.00)              sipowicz (p=1.00)
# News                          huie (p=1.00)               lesueur (p=1.00)
# Reality-TV                     occ (p=1.00)         jarrod brandi (p=1.00)
# Romance                     dimera (p=1.00)   forrester creations (p=1.00)
# Sci-Fi               voltron force (p=1.00)                goauld (p=1.00)
# Short                       bitzer (p=0.98)                 jetta (p=0.98)
# Sport                       darley (p=1.00)        round coverage (p=1.00)
# Talk-Show             actorse chat (p=1.00)  talented individuals (p=1.00)
# Thriller                  sipowicz (p=1.00)                 gelai (p=1.00)
# War                         ruping (p=0.99)                 dufei (p=0.99)
# Western                    alcalde (p=1.00)               clanton (p=1.00)
#
#                                        P5                            P6  \
# Action                   smissen (p=1.00)          ter smissen (p=1.00)
# Adult               undress lick (p=0.78)           pussy lick (p=0.77)
# Adventure                 mowgli (p=1.00)             wordgirl (p=1.00)
# Animation                 yakari (p=1.00)          logger vick (p=1.00)
# Biography              swiftnick (p=0.99)        ryge petersen (p=0.99)
# Comedy           table panelists (p=1.00)              beakman (p=1.00)
# Crime                      kensi (p=1.00)          malloy reed (p=1.00)
# Documentary     host christopher (p=1.00)  christopher kimball (p=1.00)
# Drama                      lowie (p=1.00)               eliane (p=1.00)
# Family            charley weaver (p=1.00)            mr robson (p=1.00)
# Fantasy                    krabs (p=1.00)               iolaus (p=1.00)
# Game-Show               warhurst (p=1.00)     hollywood square (p=1.00)
# History                   darley (p=1.00)               hajjaj (p=1.00)
# Horror                   adalind (p=0.99)              kolchak (p=0.99)
# Music           televisions sing (p=1.00)      sing troubadour (p=1.00)
# Musical                    duder (p=0.98)                wakko (p=0.98)
# Mystery                  volodya (p=1.00)                gelai (p=1.00)
# News         rebroadcast profile (p=1.00)          daily orbit (p=1.00)
# Reality-TV                 melai (p=1.00)            matt froy (p=1.00)
# Romance            hope memorial (p=1.00)                 reva (p=1.00)
# Sci-Fi                     sisko (p=1.00)                adama (p=1.00)
# Short                 richy show (p=0.98)  welcome adventurers (p=0.98)
# Sport              bladebreakers (p=1.00)         coach taylor (p=0.99)
# Talk-Show         fashion health (p=1.00)        star harrison (p=1.00)
# Thriller                   witse (p=1.00)              de cock (p=1.00)
# War                  mchale crew (p=0.99)                klink (p=0.99)
# Western                    heyes (p=1.00)           jim hardie (p=1.00)
#
#                                      P7                                P8  \
# Action                 vilches (p=1.00)                    tealc (p=1.00)
# Adult              sweet pussy (p=0.77)           others pussies (p=0.76)
# Adventure              tod buz (p=1.00)          discovery jones (p=1.00)
# Animation               molang (p=1.00)                    peppa (p=1.00)
# Biography          heising eye (p=0.99)  entertainment interview (p=0.99)
# Comedy            host chelsea (p=1.00)                play know (p=1.00)
# Crime                 sipowicz (p=1.00)                    nucky (p=1.00)
# Documentary       julia collin (p=1.00)           collin davison (p=1.00)
# Drama                mrs tembe (p=1.00)                     edda (p=1.00)
# Family           underdog show (p=1.00)           square welcome (p=1.00)
# Fantasy               iznogoud (p=1.00)                    zatch (p=1.00)
# Game-Show       charley weaver (p=1.00)                     cerf (p=1.00)
# History              al hajjaj (p=1.00)                   aafrin (p=1.00)
# Horror                michonne (p=0.99)      winchester brothers (p=0.99)
# Music               host anita (p=1.00)           lane orchestra (p=1.00)
# Musical               rosalina (p=0.98)                  sporall (p=0.98)
# Mystery                  witse (p=1.00)                  de cock (p=1.00)
# News                baker alex (p=1.00)        panelists include (p=1.00)
# Reality-TV           shop rick (p=1.00)              chef ramsay (p=1.00)
# Romance                  pacey (p=1.00)                  vilches (p=1.00)
# Sci-Fi           mulder scully (p=1.00)                   cylons (p=1.00)
# Short        adventurers today (p=0.98)         safe adventurers (p=0.98)
# Sport                     anik (p=0.99)                 jon anik (p=0.99)
# Talk-Show     sport television (p=1.00)       massachusetts base (p=1.00)
# Thriller                 kojak (p=1.00)            mulder scully (p=1.00)
# War                    hotlips (p=0.99)              china beach (p=0.99)
# Western           slim sherman (p=1.00)               trail boss (p=1.00)
#
#                                          P9                             P10
# Action                       luffy (p=1.00)             noorderzon (p=1.00)
# Adult                  tongue fuck (p=0.74)              hard cock (p=0.70)
# Adventure                   goauld (p=1.00)               inuyasha (p=1.00)
# Animation                    luffy (p=1.00)                 mowgli (p=1.00)
# Biography          david eisenbach (p=0.98)              eisenbach (p=0.98)
# Comedy               chelsea round (p=1.00)           chelsea chat (p=1.00)
# Crime                        witse (p=1.00)              ashfordly (p=1.00)
# Documentary           cook bridget (p=1.00)      bridget lancaster (p=1.00)
# Drama                       dimera (p=1.00)              itumeleng (p=1.00)
# Family                       balki (p=1.00)                 mowgli (p=1.00)
# Fantasy                     ichigo (p=1.00)                  sayid (p=1.00)
# Game-Show            underdog show (p=1.00)         square welcome (p=1.00)
# History                 chef staib (p=1.00)  interview congressman (p=1.00)
# Horror                   skull boy (p=0.99)           neitherworld (p=0.99)
# Music               musical stroll (p=1.00)          moppet sloane (p=1.00)
# Musical                    quellor (p=0.98)                 avilon (p=0.98)
# Mystery                      kojak (p=1.00)          mulder scully (p=1.00)
# News         rebroadcast interview (p=1.00)       rebroadcast look (p=1.00)
# Reality-TV               turtleman (p=1.00)              quickfire (p=1.00)
# Romance                      jabot (p=1.00)               carolees (p=1.00)
# Sci-Fi                       quark (p=1.00)                 numbuh (p=1.00)
# Short                   swift safe (p=0.98)             show richy (p=0.98)
# Sport                    pat corey (p=0.99)               beyblade (p=0.99)
# Talk-Show          television live (p=1.00)     promotions publish (p=1.00)
# Thriller                       imf (p=1.00)     detectives briscoe (p=1.00)
# War                    claudia joy (p=0.99)             von strohm (p=0.99)
# Western                judge garth (p=1.00)            jess harper (p=1.00)

# %% [markdown]
# ### TF-IDF + SVC

# %% [markdown]
# #### Summary
# * LinearSVC doesnt output probabilities. Hence the probability threshold is not used for SVC
# * SVC + TF-IDF obtains the best overall F1 score with Binary Relevance of 0.77 with the below models
#     * TfidfVectorizer(max_df=0.5, min_df=2, ngram_range=(1, 2))
#     * OneVsRestClassifier(LinearSVC(C=1, class_weight='balanced'))

# %% [markdown]
# #### Grid Search CV

# %%
# LinearSVC
pipeline = Pipeline([
            ('tfidf', TfidfVectorizer()),
            ('clf', OneVsRestClassifier(LinearSVC(), n_jobs=1)),
            ])
parameters = {
            'tfidf__max_df': (0.25, 0.5),
            'tfidf__min_df': (1, 3),
            'tfidf__ngram_range': [(1, 1), (1, 2)],
            "clf__estimator__C": [1, 10],
            "clf__estimator__class_weight": ['balanced'],
            }

grid_search_cv = GridSearchCV(pipeline, parameters, cv=2, n_jobs=4, verbose=10)
grid_search_cv.fit(train_X, train_y)

print()
print("Best parameters set:")
print (grid_search_cv.best_estimator_.steps)
print()

# measuring performance on test set
print ("Applying best classifier on test data:")
best_clf = grid_search_cv.best_estimator_
predictions = best_clf.predict(test_X) 
accuracy(test_y, predictions)
# Out:
# Fitting 2 folds for each of 16 candidates, totalling 32 fits
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed: 37.6min
# [Parallel(n_jobs=4)]: Done  29 out of  32 | elapsed: 50.5min remaining:  5.2min
# [Parallel(n_jobs=4)]: Done  32 out of  32 | elapsed: 56.2min finished
# Best parameters set:
# [('tfidf', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.25, max_features=None, min_df=1,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)), ('clf', OneVsRestClassifier(estimator=LinearSVC(C=10, class_weight='balanced', dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#           n_jobs=1))]
#
# Applying best classifier on test data:
#              Precision  Recall  F1-Score  Support
# Action            0.92    0.64      0.75   4321.0
# Adult             0.00    0.00      0.00     11.0
# Adventure         0.91    0.58      0.70   3496.0
# Animation         0.92    0.70      0.80   3333.0
# Biography         0.88    0.13      0.23    354.0
# Comedy            0.85    0.73      0.79   7320.0
# Crime             0.88    0.76      0.81   4453.0
# Documentary       0.77    0.64      0.70   1863.0
# Drama             0.88    0.86      0.87  11067.0
# Family            0.90    0.65      0.76   4173.0
# Fantasy           0.92    0.54      0.68   2643.0
# Game-Show         0.92    0.70      0.79    450.0
# History           0.82    0.37      0.51    623.0
# Horror            0.92    0.31      0.46    854.0
# Music             0.91    0.54      0.68    654.0
# Musical           0.98    0.25      0.40    182.0
# Mystery           0.86    0.63      0.73   4114.0
# News              0.92    0.66      0.77    681.0
# Reality-TV        0.85    0.71      0.78   1748.0
# Romance           0.92    0.72      0.81   4581.0
# Sci-Fi            0.91    0.63      0.74   3055.0
# Short             0.94    0.11      0.20    142.0
# Sport             0.90    0.46      0.61    426.0
# Talk-Show         0.89    0.76      0.82    809.0
# Thriller          0.89    0.51      0.64   3254.0
# War               0.94    0.47      0.63    388.0
# Western           0.91    0.67      0.77    445.0
# Avg/Total         0.89    0.68      0.76  65440.0

# %% [markdown]
# #### Trying out individual hyperparameters

# %%
pipeline = Pipeline([
                ('tfidf', TfidfVectorizer(max_df=0.5, min_df=2, ngram_range=(1, 2))),
                ('clf', OneVsRestClassifier(LinearSVC(C=1, class_weight='balanced'), n_jobs=3))
            ])
pipeline.fit(train_X, train_y)

predictions = pipeline.predict(test_X) 
accuracy(test_y, predictions)
# Out:
#              Precision  Recall  F1-Score  Support
# Action            0.88    0.70      0.78   4321.0
# Adult             0.00    0.00      0.00     11.0
# Adventure         0.85    0.64      0.73   3496.0
# Animation         0.88    0.76      0.81   3333.0
# Biography         0.83    0.19      0.32    354.0
# Comedy            0.82    0.77      0.79   7320.0
# Crime             0.85    0.78      0.82   4453.0
# Documentary       0.71    0.71      0.71   1863.0
# Drama             0.88    0.84      0.86  11067.0
# Family            0.85    0.71      0.77   4173.0
# Fantasy           0.87    0.61      0.71   2643.0
# Game-Show         0.90    0.74      0.81    450.0
# History           0.76    0.47      0.58    623.0
# Horror            0.86    0.38      0.53    854.0
# Music             0.88    0.61      0.72    654.0
# Musical           0.97    0.33      0.49    182.0
# Mystery           0.82    0.67      0.74   4114.0
# News              0.88    0.71      0.79    681.0
# Reality-TV        0.79    0.75      0.77   1748.0
# Romance           0.89    0.75      0.81   4581.0
# Sci-Fi            0.88    0.68      0.76   3055.0
# Short             0.90    0.13      0.23    142.0
# Sport             0.84    0.55      0.66    426.0
# Talk-Show         0.86    0.79      0.83    809.0
# Thriller          0.81    0.57      0.67   3254.0
# War               0.90    0.53      0.67    388.0
# Western           0.89    0.69      0.78    445.0
# Avg/Total         0.85    0.72      0.77  65440.0

# %% [markdown]
# ### TF-IDF + Logistic Regression

# %% [markdown]
# #### Summary
# * Logistic Regression is comparable, but still under performs Naive Bayes and LinearSVC
# * TF-IDF + Logistic Regression results in an overall F1 score of 0.74 using the below models
#     * TfidfVectorizer(max_df=0.5, min_df=2, ngram_range=(1, 1))
#     * OneVsRestClassifier(LogisticRegression(C=100))

# %% [markdown]
# #### GridSearchCV

# %%
# LinearSVC
pipeline = Pipeline([
            ('tfidf', TfidfVectorizer()),
            ('clf', OneVsRestClassifier(LogisticRegression(), n_jobs=1)),
            ])
parameters = {
            'tfidf__max_df': [0.25, 0.5, 0.75],
            'tfidf__min_df': [1, 2],
            'tfidf__ngram_range': [(1, 1), (1, 2)],
            "clf__estimator__C": [0.1, 1],
            }

grid_search_cv = GridSearchCV(pipeline, parameters, cv=2, n_jobs=3, verbose=10)
grid_search_cv.fit(train_X, train_y)

print()
print("Best parameters set:")
print (grid_search_cv.best_estimator_.steps)
print()

# measuring performance on test set
print ("Applying best classifier on test data:")
best_clf = grid_search_cv.best_estimator_
prob, predictions = multi_label_predict(best_clf, test_X, prob_thresh) 
accuracy(test_y, predictions)
# Out:
# Fitting 2 folds for each of 24 candidates, totalling 48 fits
# [Parallel(n_jobs=3)]: Done   2 tasks      | elapsed:   55.8s
# [Parallel(n_jobs=3)]: Done   7 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=3)]: Done  12 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=3)]: Done  19 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=3)]: Done  26 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed: 24.0min
# [Parallel(n_jobs=3)]: Done  48 out of  48 | elapsed: 35.2min remaining:    0.0s
# [Parallel(n_jobs=3)]: Done  48 out of  48 | elapsed: 35.2min finished
# Best parameters set:
# [('tfidf', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.5, max_features=None, min_df=2,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)), ('clf', OneVsRestClassifier(estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#           n_jobs=1))]
#
# Applying best classifier on test data:
#              Precision  Recall  F1-Score  Support
# Action            0.57    0.87      0.69   4321.0
# Adult             0.00    1.00      0.00     11.0
# Adventure         0.50    0.86      0.63   3496.0
# Animation         0.54    0.93      0.68   3333.0
# Biography         0.06    0.86      0.11    354.0
# Comedy            0.70    0.82      0.76   7320.0
# Crime             0.68    0.88      0.77   4453.0
# Documentary       0.35    0.91      0.51   1863.0
# Drama             0.86    0.83      0.85  11067.0
# Family            0.56    0.87      0.68   4173.0
# Fantasy           0.44    0.86      0.59   2643.0
# Game-Show         0.24    0.94      0.38    450.0
# History           0.14    0.88      0.24    623.0
# Horror            0.14    0.86      0.25    854.0
# Music             0.26    0.89      0.40    654.0
# Musical           0.03    0.85      0.07    182.0
# Mystery           0.58    0.83      0.68   4114.0
# News              0.27    0.94      0.42    681.0
# Reality-TV        0.37    0.91      0.53   1748.0
# Romance           0.68    0.81      0.74   4581.0
# Sci-Fi            0.50    0.86      0.63   3055.0
# Short             0.02    0.85      0.04    142.0
# Sport             0.13    0.92      0.23    426.0
# Talk-Show         0.33    0.95      0.49    809.0
# Thriller          0.45    0.84      0.58   3254.0
# War               0.12    0.89      0.21    388.0
# Western           0.15    0.91      0.25    445.0
# Avg/Total         0.58    0.86      0.67  65440.0

# %% [markdown]
# #### A Single Hyperparameter

# %%
pipeline = Pipeline([
                ('tfidf', TfidfVectorizer(max_df=0.5, min_df=2, ngram_range=(1, 1))),
                ('clf', OneVsRestClassifier(LogisticRegression(C=100)))
            ])
pipeline.fit(train_X, train_y)
prob, predictions = multi_label_predict(pipeline, test_X, prob_thresh) 
accuracy(test_y, predictions)
# Out:
#              Precision  Recall  F1-Score  Support
# Action            0.74    0.79      0.76   4321.0
# Adult             0.08    0.27      0.12     11.0
# Adventure         0.67    0.76      0.71   3496.0
# Animation         0.74    0.85      0.79   3333.0
# Biography         0.20    0.56      0.30    354.0
# Comedy            0.74    0.79      0.76   7320.0
# Crime             0.76    0.82      0.79   4453.0
# Documentary       0.48    0.76      0.59   1863.0
# Drama             0.86    0.82      0.84  11067.0
# Family            0.69    0.79      0.73   4173.0
# Fantasy           0.65    0.75      0.70   2643.0
# Game-Show         0.57    0.89      0.69    450.0
# History           0.37    0.69      0.48    623.0
# Horror            0.36    0.66      0.46    854.0
# Music             0.53    0.79      0.64    654.0
# Musical           0.25    0.66      0.36    182.0
# Mystery           0.69    0.74      0.71   4114.0
# News              0.52    0.81      0.64    681.0
# Reality-TV        0.54    0.82      0.65   1748.0
# Romance           0.78    0.81      0.79   4581.0
# Sci-Fi            0.70    0.79      0.74   3055.0
# Short             0.10    0.49      0.17    142.0
# Sport             0.45    0.81      0.58    426.0
# Talk-Show         0.56    0.87      0.68    809.0
# Thriller          0.62    0.72      0.67   3254.0
# War               0.47    0.75      0.58    388.0
# Western           0.51    0.85      0.64    445.0
# Avg/Total         0.70    0.79      0.74  65440.0

# %% [markdown]
# ### CountVectorizer + SVC

# %% [markdown]
# #### Summary
# * Compared to TF-IDF, the best CountVectorizer results in lower overall F1-score
# * Best CountVectorizer + LinearSVC model results in overall F1 score of 0.72 (vs. 0.76 using TF-IDF + LinearSVC)
#     * CountVectorizer(max_df=0.5, min_df=2, ngram_range=(1, 2))
#     * OneVsRestClassifier(LinearSVC(C=1, class_weight='balanced'))

# %% [markdown]
# #### GridSearchCV

# %%
# LinearSVC
pipeline = Pipeline([
            ('cvec', CountVectorizer()),
            ('clf', OneVsRestClassifier(LinearSVC())),
            ])
parameters = {
            'cvec__max_df': (0.25, 0.5),
            'cvec__min_df': (1, 2),
            'cvec__ngram_range': [(1, 1), (1, 2)],
            "clf__estimator__C": [1, 10, 100],
            "clf__estimator__class_weight": ['balanced'],
            }

grid_search_cv = GridSearchCV(pipeline, parameters, cv=2, verbose=10, scoring=overall_f1_score_v1_cv)
grid_search_cv.fit(train_X, train_y)

print()
print("Best parameters set:")
print (grid_search_cv.best_estimator_.steps)
print()

# measuring performance on test set
print ("Applying best classifier on test data:")
best_clf = grid_search_cv.best_estimator_
predictions = best_clf.predict(test_X) 
accuracy(test_y, predictions)
# Out:
# Fitting 2 folds for each of 24 candidates, totalling 48 fits
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.4440220688061469, total= 1.8min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.0min remaining:    0.0s
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.4466370587427316, total= 1.8min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  3.8min remaining:    0.0s
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.45731483723665545, total= 7.0min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 11.0min remaining:    0.0s
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.4716954072050538, total= 7.6min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed: 18.7min remaining:    0.0s
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.4389842344004588, total= 1.8min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 20.6min remaining:    0.0s
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.44249460043196537, total= 1.7min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 22.3min remaining:    0.0s
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.46389068342436524, total= 3.9min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 26.3min remaining:    0.0s
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.4748754246520593, total= 3.5min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 30.0min remaining:    0.0s
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.4442082399426947, total= 1.7min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 31.8min remaining:    0.0s
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.4465810498363207, total= 1.9min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.45767621944895776, total= 7.1min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.47188417673973915, total= 6.9min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.4391174283492368, total= 1.5min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.44288100420104265, total= 1.4min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.4641081518405909, total= 3.4min
# [CV] clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=1, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.47501418183693467, total= 3.3min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.4370594742359394, total= 1.6min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.43869544739169897, total= 1.8min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.4560552290118665, total= 7.3min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.4705222246551347, total= 7.8min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.43078991443448145, total= 1.5min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.43332636727685553, total= 1.6min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.4622069245316355, total= 3.6min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.47270822826550807, total= 3.7min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.4371229752104392, total= 1.6min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.438447752963882, total= 1.6min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.4564783777045184, total= 7.9min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.47087229225518296, total= 7.9min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.43088458163835053, total= 1.5min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.43319138361440884, total= 1.5min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.46235060933728434, total= 3.9min
# [CV] clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=10, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.47300415619000835, total= 3.9min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.435936785170343, total= 1.7min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.43758838340289036, total= 1.9min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.45586206418424713, total= 7.1min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.47038854553792037, total= 7.7min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.4291473080076524, total= 1.5min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.4320820925462365, total= 1.5min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.4619592958576009, total= 3.3min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.25, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.47259233399921124, total= 3.6min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.4358003681450353, total= 1.6min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 1), score=0.4372917576231071, total= 1.8min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.4563527798174035, total= 6.1min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=1, cvec__ngram_range=(1, 2), score=0.4700296654585813, total=47.0min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.42924829157175404, total= 2.0min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 1), score=0.43222601887262113, total= 1.6min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.46189415771548337, total= 3.5min
# [CV] clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2)
# [CV]  clf__estimator__C=100, clf__estimator__class_weight=balanced, cvec__max_df=0.5, cvec__min_df=2, cvec__ngram_range=(1, 2), score=0.4723384712906126, total= 3.7min
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 215.7min finished
# Best parameters set:
# [('cvec', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.5, max_features=None, min_df=2,
#         ngram_range=(1, 2), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)), ('clf', OneVsRestClassifier(estimator=LinearSVC(C=1, class_weight='balanced', dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#           n_jobs=1))]
#
# Applying best classifier on test data:
#              Precision  Recall  F1-Score  Support
# Action            0.88    0.59      0.71   4321.0
# Adult             0.00    0.00      0.00     11.0
# Adventure         0.87    0.53      0.66   3496.0
# Animation         0.89    0.67      0.76   3333.0
# Biography         0.75    0.16      0.27    354.0
# Comedy            0.81    0.71      0.76   7320.0
# Crime             0.88    0.68      0.76   4453.0
# Documentary       0.75    0.60      0.67   1863.0
# Drama             0.89    0.78      0.83  11067.0
# Family            0.87    0.62      0.72   4173.0
# Fantasy           0.87    0.50      0.64   2643.0
# Game-Show         0.93    0.66      0.77    450.0
# History           0.78    0.36      0.50    623.0
# Horror            0.80    0.30      0.44    854.0
# Music             0.88    0.51      0.65    654.0
# Musical           0.88    0.24      0.38    182.0
# Mystery           0.86    0.55      0.67   4114.0
# News              0.90    0.65      0.75    681.0
# Reality-TV        0.80    0.68      0.73   1748.0
# Romance           0.90    0.67      0.77   4581.0
# Sci-Fi            0.88    0.57      0.69   3055.0
# Short             0.81    0.12      0.21    142.0
# Sport             0.83    0.43      0.57    426.0
# Talk-Show         0.88    0.71      0.79    809.0
# Thriller          0.84    0.46      0.59   3254.0
# War               0.90    0.42      0.57    388.0
# Western           0.86    0.60      0.71    445.0
# Avg/Total         0.86    0.63      0.72  65440.0

# %% [markdown]
# #### Single Hyperparameter Tuning

# %%
pipeline = Pipeline([
                ('cvec', CountVectorizer(max_df=0.5, min_df=1, ngram_range=(1, 1))),
                ('clf', OneVsRestClassifier(LinearSVC(C=1, class_weight='balanced')))
            ])
pipeline.fit(train_X, train_y)

predictions = pipeline.predict(test_X) 
accuracy(test_y, predictions)
# Out:
#              Precision  Recall  F1-Score  Support
# Action            0.79    0.64      0.71   4321.0
# Adult             0.00    0.00      0.00     11.0
# Adventure         0.74    0.59      0.65   3496.0
# Animation         0.82    0.71      0.76   3333.0
# Biography         0.47    0.23      0.31    354.0
# Comedy            0.74    0.74      0.74   7320.0
# Crime             0.79    0.71      0.74   4453.0
# Documentary       0.56    0.61      0.58   1863.0
# Drama             0.85    0.79      0.82  11067.0
# Family            0.72    0.66      0.69   4173.0
# Fantasy           0.75    0.56      0.64   2643.0
# Game-Show         0.82    0.63      0.71    450.0
# History           0.59    0.41      0.49    623.0
# Horror            0.56    0.38      0.45    854.0
# Music             0.74    0.56      0.64    654.0
# Musical           0.66    0.30      0.42    182.0
# Mystery           0.73    0.60      0.66   4114.0
# News              0.75    0.64      0.69    681.0
# Reality-TV        0.59    0.69      0.64   1748.0
# Romance           0.80    0.72      0.76   4581.0
# Sci-Fi            0.77    0.63      0.70   3055.0
# Short             0.50    0.17      0.25    142.0
# Sport             0.71    0.49      0.58    426.0
# Talk-Show         0.74    0.71      0.72    809.0
# Thriller          0.69    0.55      0.61   3254.0
# War               0.79    0.47      0.59    388.0
# Western           0.74    0.65      0.69    445.0
# Avg/Total         0.75    0.67      0.71  65440.0

# %%
pipeline = Pipeline([
                ('cvec', CountVectorizer(max_df=0.5, min_df=1, ngram_range=(1, 2))),
                ('clf', OneVsRestClassifier(LinearSVC(C=1, class_weight='balanced')))
            ])
pipeline.fit(train_X, train_y)

predictions = pipeline.predict(test_X) 
accuracy(test_y, predictions)
# Out:
#              Precision  Recall  F1-Score  Support
# Action            0.91    0.53      0.67   4321.0
# Adult             0.00    0.00      0.00     11.0
# Adventure         0.90    0.47      0.61   3496.0
# Animation         0.91    0.61      0.73   3333.0
# Biography         0.79    0.12      0.20    354.0
# Comedy            0.84    0.69      0.76   7320.0
# Crime             0.89    0.64      0.75   4453.0
# Documentary       0.80    0.56      0.66   1863.0
# Drama             0.90    0.77      0.83  11067.0
# Family            0.90    0.56      0.69   4173.0
# Fantasy           0.90    0.43      0.58   2643.0
# Game-Show         0.94    0.62      0.75    450.0
# History           0.82    0.29      0.43    623.0
# Horror            0.87    0.24      0.38    854.0
# Music             0.90    0.45      0.60    654.0
# Musical           0.91    0.18      0.29    182.0
# Mystery           0.89    0.50      0.64   4114.0
# News              0.93    0.62      0.74    681.0
# Reality-TV        0.85    0.65      0.73   1748.0
# Romance           0.92    0.64      0.75   4581.0
# Sci-Fi            0.91    0.53      0.67   3055.0
# Short             0.87    0.09      0.17    142.0
# Sport             0.87    0.36      0.51    426.0
# Talk-Show         0.89    0.68      0.77    809.0
# Thriller          0.88    0.40      0.55   3254.0
# War               0.93    0.37      0.53    388.0
# Western           0.90    0.57      0.70    445.0
# Avg/Total         0.89    0.59      0.70  65440.0
